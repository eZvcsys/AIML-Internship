# %% [markdown]
# #  Pandas Library
#
# ## Installation
# pip install pandas

# %%
# Import convention
import pandas as pd

# %%
s = pd.Series(
  [10, 20, 30, 40],
  index=['ten','b','thirty','d']
)
print(s['ten'])  # 20
print(s.mean()) # 25.0

# %%
df = pd.read_csv("store_data.csv")

# %%
print(df.head())
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
print(df.info())

# Summary statistics
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Drop duplicates if any
df = df.drop_duplicates()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  str
#  1   order_date      51290 non-null  str
#  2   ship_date       51290 non-null  str
#  3   ship_mode       51290 non-null  str
#  4   customer_name   51290 non-null  str
#  5   segment         51290 non-null  str
#  6   state           51290 non-null  str
#  7   country         51290 non-null  str
#  8   market          51290 non-null  str
#  9   region          51290 non-null  str
#  10  product_id      51290 non-null  str
#  11  category        51290 non-null  str
#  12  sub_category    51290 non-null  str
#  13  product_name    51290 non-null  str
#  14  sales           51290 non-null  str
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
# ...

# %%
## Project 1

import pandas as pd

# Load CSV file
df = pd.read_csv("store_data.csv")

# Preview first 5 rows
print(df.head())
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  06-01-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  05-01-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  05-01-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
# Check structure
#print(df.info())

# # Summary statistics
#print(df.describe())

# # Check for missing values
#print(df.isnull().sum())

# # Drop duplicates if any
#df = df.drop_duplicates()

# %%
"""
* Total sales
* Total profit
* Total revenue
"""
total_sales = df['sales'].sum() # 4500
total_profit = df['profit'].sum() # 5,00,000
revenue_df = df['profit'] + df['shipping_cost'] # 8,00,000
total_revenue = revenue_df.sum()

# %%
"""
Year category, sales
"""
year_sales_data = df[['year', 'sales']]
#print(year_sales_data)

country_sales_data = df[['country', 'sales']]
print(country_sales_data)
# Out:
#              country sales
# 0            Algeria   408
# 1          Australia   120
# 2            Hungary    66
# 3             Sweden    45
# 4          Australia   114
# ...              ...   ...
# 51285  United States    14
# 51286        Morocco     4
# 51287      Nicaragua    26
# 51288         Mexico     7
# 51289  United States     3
#
# [51290 rows x 2 columns]
